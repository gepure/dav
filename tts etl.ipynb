# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import geoalchemy2 as geo
from sqlalchemy import create_engine
pd.options.display.max_rows = 999

# %% [markdown]
# read Transportation Toronto csv files to transform and join with ward layer

# %%
engine = create_engine('postgresql://postgres:1234@172.19.118.205:5432/walkability')
sql = "select * from tts2016_ward"
df = pd.read_sql_query(sql,con=engine)

# %%
df['field_1']
# Out:
# 0                             Total Number of households
# 1                                       Number of houses
# 2                                   Number of apartments
# 3                                   Number of townhouses
# 4                     Number of households with 1 person
# 5                    Number of households with 2 persons
# 6                    Number of households with 3 persons
# 7                    Number of households with 4 persons
# 8            Number of households with 5 or more persons
# 9                    Number of households with 0 vehicle
# 10                  Number of households with 1 vehicles
# 11                  Number of households with 2 vehicles
# 12                  Number of households with 3 vehicles
# 13                  Number of households with 4 vehicles
# 14          Number of households with 5 or more vehicles
# 15     Number of households with unknown number of ve...
# ...

# %% [markdown]
# Showing how split works. Assign index and it outputs the first letter of the string

# %%
nt = "Number of trips by residents by walk mode during afternoon peak period (15:00 p.m. to 17:59 p.m.)"
nt[0]
# Out:
# 'N'

# %%
nt = "Number of trips by residents by walk mode during morning peak period (6:00 a.m. to 8:59 a.m.)"

# %%
nt = "Number of trips made to the area by motorcycle during afternoon peak period (15:00 p.m. to 17:59 p.m.)"

# %%
nt = "Number of houses"

# %%
nt = "Number of apartments"

# %%
nt = "Number of townhouses"

# %%
nt = "Number of households with 1 person"

# %%
nt = "Number of persons between 10 and 14 years old"

# %% [markdown]
# splitting string

# %%
nt.split()[0]
print(nt.split())
# Out:
# ['Number', 'of', 'trips', 'by', 'residents', 'by', 'walk', 'mode', 'during', 'afternoon', 'peak', 'period', '(15:00', 'p.m.', 'to', '17:59', 'p.m.)']

# %% [markdown]
# Returns first letter

# %%
nt.split()[0][0]
# Out:
# 'N'

# %% [markdown]
# replacing text string Number of trips by residents with n_trip_res
# replacing the colons, commas and periods in (15:00 p.m. to 17:59 p.m.) with blanks
# replacing the word "by" and "mode" with blanks

# %%
#test_str = 'Number of home-based discretionary trips by residents during afternoon peak period (15:00 p.m. to 17:59 p.m.)'
#test_str = 'Number of home-based discretionary trips by residents in 24-hour'
#test_str = 'Number of trips by residents by paid rideshare mode during afternoon peak period (15:00 p.m. to 17:59 p.m.)'
#test_str = 'Number of trips by residents by joint GO rail and public transit during afternoon peak period (15:00 p.m. to 17:59 p.m.)'
#test_str = 'Number of trips made from the area by transit excluding GO rail during morning peak period (6:00 a.m. to 8:59 a.m.)'
#test_str = 'Number of trips made from the area by school bus during morning peak period (6:00 a.m. to 8:59 a.m.)'
#test_str = 'Number of transit trips made by residents with TTC Subway/RT'
#test_str = 'Number of trips made to the area by walk mode during morning peak period (6:00 a.m. to 8:59 a.m.)'
#test_str = 'Number of non-home-based trips by residents during afternoon peak period (15:00 p.m. to 17:59 p.m.)'
#test_str = 'Number of households with unknown number of licenced drivers'
#test_str = 'Number of households with 5 or more work-at-home employees'
#test_str = 'Number of households with 5 or more persons'
#test_str = 'Number of households with unknown number of vehicles'
#test_str = 'Number of Households with income $100000 to $124999'
#test_str = 'Number of persons between 10 and 14 years old'
test_str = 'Number of persons with work in manufacturing/construction/trade'




replace_lookup = {
    "Number":"num",
    " number":" num",
    " of":"",
    " by":"",
    " period":"",
    " old":"",
    " between":" btw",
    " public":" pub",
    " during":"",
    " residents":"",
    " transit":" trans",
    " afternoon": "",
    " trips": " trip",
    " households": " household",
    " drivers": " driver",
    " employees": " employee",
    " persons": " person",
    " vehicles": " vehicle",
    " years":" yr",
    " discretionary":" discretion",
    " the":"",
    " to":"",
    " from":"",
    " excluding":" exclude",
    " made":"",
    " area":"",
    " and":"",
    " joint":"",
    " morning":"",
    " mode":"",
    " with": "",
    " or":"",
    #" in ":"",
    "-at-":" ",
    "24-hour":"24hrs",
    "/":" ",
    "-":" ",
    ".":"",
    ":":"",
    "(":"",
    ")":"",
    " am":"",
    " pm":"",
    " $":" ",
 
}

for k,v in replace_lookup.items():
    test_str = test_str.replace(k,v)
    print(test_str,'\n\n')

print('_____________________\n',test_str,'\n\n')
test_str= test_str.lower().replace(' ','_')
print('_____________________\n',test_str,'\n\n')
len(test_str)
# Out:
# num of persons with work in manufacturing/construction/trade
#
#
# num of persons with work in manufacturing/construction/trade
#
#
# num persons with work in manufacturing/construction/trade
#
#
# num persons with work in manufacturing/construction/trade
#
#
# num persons with work in manufacturing/construction/trade
#
#
# num persons with work in manufacturing/construction/trade
#
#
# num persons with work in manufacturing/construction/trade
#
#
# num persons with work in manufacturing/construction/trade
#
#
# num persons with work in manufacturing/construction/trade
#
#
# num persons with work in manufacturing/construction/trade
#
#
# num persons with work in manufacturing/construction/trade
#
#
# num persons with work in manufacturing/construction/trade
#
#
# num persons with work in manufacturing/construction/trade
#
#
# num persons with work in manufacturing/construction/trade
#
#
# num persons with work in manufacturing/construction/trade
#
#
# ...

# %%
nt1 = nt.replace("Number of trips by residents","num trip res").replace("Number of trips made to the area","num trip res").replace("Number of houses", "num houses").replace("Number of apartments", "num apartments").replace("Number of townhouses", "num townhouses").replace("Number of households","num households").replace("Number of persons","num persons")
nt2 = nt1.replace(":","").replace(".","").replace("(","").replace(")","").replace(" by","").replace(" mode","").replace(" during","")
nt3 = nt2.replace("1500 pm to 1759 pm","1500 1759").replace("600 am to 859 am","600 859")
nt4 = nt3.replace("afternoon peak period","aft noon peak")
print(nt1,"\n",nt2,"\n",nt3,"\n",nt4)
# Out:
# num persons between 10 and 14 years old
#  num persons between 10 and 14 years old
#  num persons between 10 and 14 years old
#  num persons between 10 and 14 years old

# %% [markdown]
# replacing space with underscore
# setting all text to lower case

# %%
nt5 = nt4.replace(" ", "_")
nt6 = nt5.lower()
##nt3 = nt2.split("_")
print(nt5,"\n",nt6)
str = nt6
len(str)
# Out:
# num_persons_between_10_and_14_years_old
#  num_persons_between_10_and_14_years_old
# 39

# %%
# Creating SQLAlchemy's engine to use
engine = create_engine('postgresql://username:password@host:socket/database')


geodataframe = gpd.GeoDataFrame(pd.DataFrame.from_csv('<your dataframe source>'))
#... [do something with the geodataframe]

geodataframe['geom'] = geodataframe['geometry'].apply(lambda x: WKTElement(x.wkt, srid=<your_SRID>)

#drop the geometry column as it is now duplicative
geodataframe.drop('geometry', 1, inplace=True)

# Use 'dtype' to specify column's type
# For the geom column, we will use GeoAlchemy's type 'Geometry'
geodataframe.to_sql(table_name, engine, if_exists='append', index=False, 
                         dtype={'geom': Geometry('POINT', srid= <your_srid>)})

# %%
gdf = gpd.read_file
